# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
inmuebles24_df = pd.read_csv('csv_files/COMPLETE_inmuebles_24_CDMX.csv', encoding = 'utf16')
inmuebles24_df
# Out:
#                                   Nombre de Publicación            Estado  \
# 0     Magnífica Casa en Una de Las Mejores Colonias ...  Distrito Federal
# 1      Casa en Venta en Xochimilco Santa Cruz Acalpixca  Distrito Federal
# 2                   Se Vende Casa. San Jerónimo Aculco.  Distrito Federal
# 3                      Excelente Residencia en Pedregal  Distrito Federal
# 4     Residencia en Venta en Lomas de Chapultepec, C...  Distrito Federal
# ...                                                 ...               ...
# 2468     Departamento Nuevo en Venta Nápoles Dh 20 2541  Distrito Federal
# 2469      Estudio Departamento en Venta Del. Cuauhtemoc  Distrito Federal
# 2470  Departamento Tipo Estudio en Venta Delegacion ...  Distrito Federal
# 2471  Loft en Venta en San Diego Churubusco en Coyoa...  Distrito Federal
# 2472                                      Depa Santa Fe  Distrito Federal
#
#                        Ciudad                Colonia  \
# ...

# %%
dt_string = 'Inmuebles 24'
inmuebles24_df.index = pd.Series([dt_string] * len(inmuebles24_df))
inmuebles24_df = inmuebles24_df.reset_index()
inmuebles24_df = inmuebles24_df.rename(columns={"index":"source_of_info"})
inmuebles24_df.head(2)
# Out:
#   source_of_info                              Nombre de Publicación  \
# 0   Inmuebles 24  Magnífica Casa en Una de Las Mejores Colonias ...
# 1   Inmuebles 24   Casa en Venta en Xochimilco Santa Cruz Acalpixca
#
#              Estado           Ciudad               Colonia  \
# 0  Distrito Federal   Miguel Hidalgo  Lomas de Chapultepec
# 1  Distrito Federal       Xochimilco  Santa Cruz Acalpixca
#
#                 Avenida Tipo de propiedad Tipo de Operación  \
# 0          Sierra Gorda              Casa             Venta
# 1  Santa Cruz Acalpixca              Casa             Venta
#
#   Condición del Inmueble     Precio  ...  Número de baños completos  \
# 0         40  Antigüedad  109616013  ...                          3
# 1         15  Antigüedad    2000000  ...                          2
#
#   Número de m2  Unidad de medida  \
# 0         2000                m²
# 1         2000                m²
#
#                               Link de la publicación  \
# ...

# %%
inmuebles24_df.shape
# Out:
# (2473, 23)

# %%
sorted_columns = ['Nombre de Publicación',
 'Estado',
 'Ciudad',
 'Colonia',
 'Avenida',
 'Tipo de propiedad',
 'Tipo de Operación',
 'Condición del Inmueble',
 'Precio',
 'Precio por m2',
 'Moneda',
 'Número de recámaras',
 'Número de baños completos',
 'Número de m2',
 'Unidad de medida',
 'Link de la publicación',
 'Foto de publicación',
 'Real State Agency?',
 'Latitud',
 'Longitud',
 'ID',
 'updated_at',
 'source_of_info']

# %%
inmuebles24_df = inmuebles24_df[sorted_columns]
inmuebles24_df.head(2)
# Out:
#                                Nombre de Publicación            Estado  \
# 0  Magnífica Casa en Una de Las Mejores Colonias ...  Distrito Federal
# 1   Casa en Venta en Xochimilco Santa Cruz Acalpixca  Distrito Federal
#
#             Ciudad               Colonia               Avenida  \
# 0   Miguel Hidalgo  Lomas de Chapultepec          Sierra Gorda
# 1       Xochimilco  Santa Cruz Acalpixca  Santa Cruz Acalpixca
#
#   Tipo de propiedad Tipo de Operación Condición del Inmueble     Precio  \
# 0              Casa             Venta         40  Antigüedad  109616013
# 1              Casa             Venta         15  Antigüedad    2000000
#
#    Precio por m2  ... Número de m2  Unidad de medida  \
# 0     54808.0065  ...         2000                m²
# 1      1000.0000  ...         2000                m²
#
#                               Link de la publicación  \
# 0  https://www.inmuebles24.com/propiedades/magnif...
# 1  https://www.inmuebles24.com/propiedades/casa-e...
#
# ...

# %%
meli_df = pd.read_csv('csv_files/ML_departamentos_CDMX.csv', encoding = 'latin1')
meli_df
# Out:
#                                   Nombre de Publicación            Estado  \
# 0       Casa En Venta, Miguel Hidalgo, Ciudad De México  Distrito Federal
# 1       Casa En Venta, Miguel Hidalgo, Ciudad De México  Distrito Federal
# 2       Casa En Venta, Álvaro Obregón, Ciudad De México  Distrito Federal
# 3     Departamento En Venta, Miguel Hidalgo, Ciudad ...  Distrito Federal
# 4     Residencia Para Reformar, En Una De Las Coloni...  Distrito Federal
# ...                                                 ...               ...
# 1536    Ac ¡últimos Departamentos En La Colonia Centro!  Distrito Federal
# 1537  Venta Departamento En Cento De La Ciudad De Mé...  Distrito Federal
# 1538     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
# 1539  Hermoso Departamento Nuevo En El Corazón Del C...  Distrito Federal
# 1540     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
#
#               Ciudad                               Colonia  \
# ...

# %%
dt_string = 'mercado_libre'
meli_df.index = pd.Series([dt_string] * len(meli_df))
meli_df = meli_df.reset_index()
meli_df = meli_df.rename(columns={"index":"source_of_info"})

meli_df = meli_df[sorted_columns]
meli_df.head(2)
# Out:
#                              Nombre de Publicación            Estado  \
# 0  Casa En Venta, Miguel Hidalgo, Ciudad De México  Distrito Federal
# 1  Casa En Venta, Miguel Hidalgo, Ciudad De México  Distrito Federal
#
#            Ciudad                         Colonia              Avenida  \
# 0  Miguel Hidalgo  Lomas de Chapultepec I Sección  Paseo de las Palmas
# 1  Miguel Hidalgo                Lomas De Reforma    Alcázar de Toledo
#
#   Tipo de propiedad Tipo de Operación Condición del Inmueble    Precio  \
# 0              Casa             Venta          not specified  69500000
# 1              Casa             Venta          not specified  24900000
#
#    Precio por m2  ... Número de m2  Unidad de medida  \
# 0    87421.38365  ...        795.0                m²
# 1    31360.20151  ...        794.0                m²
#
#                               Link de la publicación  \
# 0  https://casa.mercadolibre.com.mx/MLM-786181310...
# ...

# %%
meli_df.shape
# Out:
# (1541, 23)

# %% [markdown]
# # Append both datasets

# %%
complete_dataset_df = inmuebles24_df.append(meli_df)
complete_dataset_df = complete_dataset_df.reset_index()
del complete_dataset_df['index']
complete_dataset_df
# Out:
#                                   Nombre de Publicación            Estado  \
# 0     Magnífica Casa en Una de Las Mejores Colonias ...  Distrito Federal
# 1      Casa en Venta en Xochimilco Santa Cruz Acalpixca  Distrito Federal
# 2                   Se Vende Casa. San Jerónimo Aculco.  Distrito Federal
# 3                      Excelente Residencia en Pedregal  Distrito Federal
# 4     Residencia en Venta en Lomas de Chapultepec, C...  Distrito Federal
# ...                                                 ...               ...
# 4009    Ac ¡últimos Departamentos En La Colonia Centro!  Distrito Federal
# 4010  Venta Departamento En Cento De La Ciudad De Mé...  Distrito Federal
# 4011     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
# 4012  Hermoso Departamento Nuevo En El Corazón Del C...  Distrito Federal
# 4013     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
#
#                        Ciudad                               Colonia  \
# ...

# %% [markdown]
# # Analysis of both datasets according to District information

# %%
sorted(complete_dataset_df['Ciudad'].unique())
# Out:
# [' Alvaro Obregón',
#  ' Azcapotzalco',
#  ' Benito Juárez',
#  ' Coyoacán',
#  ' Cuajimalpa de Morelos',
#  ' Cuauhtémoc',
#  ' Distrito Federal',
#  ' Gustavo A. Madero',
#  ' Iztacalco',
#  ' Iztapalapa',
#  ' La Magdalena Contreras',
#  ' Miguel Hidalgo',
#  ' Tlalpan',
#  ' Tláhuac',
#  ' Venustiano Carranza',
#  ' Xochimilco',
#  ' otra',
#  'Alvaro Obregón',
#  'Azcapotzalco',
#  'Benito Juárez',
#  'Coyoacán',
#  'Cuajimalpa De Morelos',
#  'Cuauhtémoc',
#  'Gustavo A. Madero',
#  'Iztacalco',
#  'Iztapalapa',
#  'La Magdalena Contreras',
#  'Miguel Hidalgo',
#  'Tlalpan',
#  'Tláhuac',
#  'Venustiano Carranza',
#  'Xochimilco']

# %%
complete_dataset_df.loc[complete_dataset_df['Ciudad']== ' Distrito Federal' , :]
# Out:
#                                   Nombre de Publicación            Estado  \
# 39                   Casa en Venta Lomas de Chapultepec  Distrito Federal
# 40                          Casa en Cdmx con Sup 500 m²  Distrito Federal
# 47                            Casa en Coyoacán (Centro)  Distrito Federal
# 48    Magnifico Departamento de 2 Niveles en La Mejo...  Distrito Federal
# 73                 Hermosa Casa en Lomas de Chapultepec  Distrito Federal
# ...                                                 ...               ...
# 2463     Acogedor Departamento en La Alcaldía Iztacalco  Distrito Federal
# 2465  Departamento Excelente Ubicacion en Ote. 245 -...  Distrito Federal
# 2469      Estudio Departamento en Venta Del. Cuauhtemoc  Distrito Federal
# 2470  Departamento Tipo Estudio en Venta Delegacion ...  Distrito Federal
# 2472                                      Depa Santa Fe  Distrito Federal
#
#                  Ciudad    Colonia  \
# 39     Distrito Federal       otra
# ...

# %%
for x in range(len(complete_dataset_df)):
    if complete_dataset_df['Ciudad'][x] == ' Distrito Federal':
        complete_dataset_df['Ciudad'][x] = complete_dataset_df['Colonia'][x]
# Out:
# <ipython-input-398-83b06b6ae4cf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete_dataset_df['Ciudad'][x] = complete_dataset_df['Colonia'][x]

# %%
sorted(complete_dataset_df['Ciudad'].unique())
# Out:
# [' Alvaro Obregón',
#  ' Azcapotzalco',
#  ' Benito Juárez',
#  ' Coyoacán',
#  ' Cuajimalpa de Morelos',
#  ' Cuauhtémoc',
#  ' Gustavo A. Madero',
#  ' Iztacalco',
#  ' Iztapalapa',
#  ' La Magdalena Contreras',
#  ' Miguel Hidalgo',
#  ' Tlalpan',
#  ' Tláhuac',
#  ' Venustiano Carranza',
#  ' Xochimilco',
#  ' otra',
#  'Alvaro Obregón',
#  'Azcapotzalco',
#  'Benito Juárez',
#  'Coyoacán',
#  'Cuajimalpa De Morelos',
#  'Cuajimalpa de Morelos',
#  'Cuauhtémoc',
#  'Gustavo A. Madero',
#  'Iztacalco',
#  'Iztapalapa',
#  'La Magdalena Contreras',
#  'Miguel Hidalgo',
#  'Tlalpan',
#  'Tláhuac',
#  'Venustiano Carranza',
#  'Xochimilco',
#  'otra']

# %%
complete_dataset_df.loc[complete_dataset_df['Ciudad']== ' Distrito Federal' , :]
# Out:
# Empty DataFrame
# Columns: [Nombre de Publicación, Estado, Ciudad, Colonia, Avenida, Tipo de propiedad, Tipo de Operación, Condición del Inmueble, Precio, Precio por m2, Moneda, Número de recámaras, Número de baños completos, Número de m2, Unidad de medida, Link de la publicación, Foto de publicación, Real State Agency?, Latitud, Longitud, ID, updated_at, source_of_info]
# Index: []
#
# [0 rows x 23 columns]

# %%
complete_dataset_df = complete_dataset_df.drop(complete_dataset_df.loc[complete_dataset_df['Ciudad'] == ' otra'].index)
complete_dataset_df = complete_dataset_df.drop(complete_dataset_df.loc[complete_dataset_df['Ciudad'] == 'otra'].index)

complete_dataset_df = complete_dataset_df.reset_index()

del complete_dataset_df['index']

# %%
for x in range(len(complete_dataset_df)):
    if complete_dataset_df['Ciudad'][x] == ' Xochimilco':
        complete_dataset_df['Ciudad'][x] = 'Xochimilco'
        
    if complete_dataset_df['Ciudad'][x] == ' Venustiano Carranza':
        complete_dataset_df['Ciudad'][x] = 'Venustiano Carranza'
        
    if complete_dataset_df['Ciudad'][x] == ' Tláhuac':
        complete_dataset_df['Ciudad'][x] = 'Tláhuac'
        
    if complete_dataset_df['Ciudad'][x] == ' Tlalpan':
        complete_dataset_df['Ciudad'][x] = 'Tlalpan'
        
    if complete_dataset_df['Ciudad'][x] == ' Miguel Hidalgo':
        complete_dataset_df['Ciudad'][x] = 'Miguel Hidalgo'
        
    if complete_dataset_df['Ciudad'][x] == ' La Magdalena Contreras':
        complete_dataset_df['Ciudad'][x] = 'La Magdalena Contreras'
        
    if complete_dataset_df['Ciudad'][x] == ' Iztapalapa':
        complete_dataset_df['Ciudad'][x] = 'Iztapalapa'
        
    if complete_dataset_df['Ciudad'][x] == ' Iztacalco':
        complete_dataset_df['Ciudad'][x] = 'Iztacalco'
        
    if complete_dataset_df['Ciudad'][x] == ' Gustavo A. Madero':
        complete_dataset_df['Ciudad'][x] = 'Gustavo A. Madero'
        
    if complete_dataset_df['Ciudad'][x] == ' Cuauhtémoc':
        complete_dataset_df['Ciudad'][x] = 'Cuauhtémoc'
        
    if complete_dataset_df['Ciudad'][x] == ' Cuajimalpa de Morelos':
        complete_dataset_df['Ciudad'][x] = 'Cuajimalpa de Morelos'
        
    if complete_dataset_df['Ciudad'][x] == ' Coyoacán':
        complete_dataset_df['Ciudad'][x] = 'Coyoacán'
        
    if complete_dataset_df['Ciudad'][x] == ' Benito Juárez':
        complete_dataset_df['Ciudad'][x] = 'Benito Juárez'
        
    if complete_dataset_df['Ciudad'][x] == ' Azcapotzalco':
        complete_dataset_df['Ciudad'][x] = 'Azcapotzalco'
        
    if complete_dataset_df['Ciudad'][x] == ' Alvaro Obregón':
        complete_dataset_df['Ciudad'][x] = 'Alvaro Obregón'
        
    if complete_dataset_df['Ciudad'][x] == 'Cuajimalpa De Morelos':
        complete_dataset_df['Ciudad'][x] = 'Cuajimalpa de Morelos'
# Out:
# <ipython-input-402-98be78f040e9>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete_dataset_df['Ciudad'][x] = 'Miguel Hidalgo'
# <ipython-input-402-98be78f040e9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete_dataset_df['Ciudad'][x] = 'Xochimilco'
# <ipython-input-402-98be78f040e9>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete_dataset_df['Ciudad'][x] = 'La Magdalena Contreras'
# ...

# %%
sorted(complete_dataset_df['Ciudad'].unique())
# Out:
# ['Alvaro Obregón',
#  'Azcapotzalco',
#  'Benito Juárez',
#  'Coyoacán',
#  'Cuajimalpa de Morelos',
#  'Cuauhtémoc',
#  'Gustavo A. Madero',
#  'Iztacalco',
#  'Iztapalapa',
#  'La Magdalena Contreras',
#  'Miguel Hidalgo',
#  'Tlalpan',
#  'Tláhuac',
#  'Venustiano Carranza',
#  'Xochimilco']

# %%
complete_dataset_df.shape
# Out:
# (3737, 23)

# %% [markdown]
# # Analysis

# %%
casas_df = complete_dataset_df.loc[complete_dataset_df['Tipo de propiedad'] == 'Casa' , :]
casas_df
# Out:
#                                   Nombre de Publicación            Estado  \
# 0     Magnífica Casa en Una de Las Mejores Colonias ...  Distrito Federal
# 1      Casa en Venta en Xochimilco Santa Cruz Acalpixca  Distrito Federal
# 2                   Se Vende Casa. San Jerónimo Aculco.  Distrito Federal
# 3                      Excelente Residencia en Pedregal  Distrito Federal
# 4     Residencia en Venta en Lomas de Chapultepec, C...  Distrito Federal
# ...                                                 ...               ...
# 3276  Departamento En Polanco, Miguel Hidalgo, Ciuda...  Distrito Federal
# 3381   Fermus Casa En Venta Iztapalapa Ciudad De México  Distrito Federal
# 3486  Fermus Casa En Venta Zona Centro Ciudad De México  Distrito Federal
# 3559        Casa De 2 Recamaras, Sala Cocina Y Comedor   Distrito Federal
# 3560  Fermus Departamento En Venta Iztapalapa Ciudad...  Distrito Federal
#
#                       Ciudad                               Colonia  \
# ...

# %%
departamentos_df = complete_dataset_df.loc[complete_dataset_df['Tipo de propiedad'] == 'Departamento' , :]
departamentos_df
# Out:
#                                   Nombre de Publicación            Estado  \
# 40             Departamento en Venta en La Condesa Cdmx  Distrito Federal
# 46    Magnifico Departamento de 2 Niveles en La Mejo...  Distrito Federal
# 69    Departamento en Venta o Renta en Jardines en L...  Distrito Federal
# 81    Exclusivos Departamentos en Preventa, Lomas de...  Distrito Federal
# 92    Departamentos en Venta a Una Cuadra del Metro ...  Distrito Federal
# ...                                                 ...               ...
# 3732    Ac ¡últimos Departamentos En La Colonia Centro!  Distrito Federal
# 3733  Venta Departamento En Cento De La Ciudad De Mé...  Distrito Federal
# 3734     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
# 3735  Hermoso Departamento Nuevo En El Corazón Del C...  Distrito Federal
# 3736     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
#
#                      Ciudad                               Colonia  \
# ...

# %%
[x for x in departamentos_df.columns]
# Out:
# ['Nombre de Publicación',
#  'Estado',
#  'Ciudad',
#  'Colonia',
#  'Avenida',
#  'Tipo de propiedad',
#  'Tipo de Operación',
#  'Condición del Inmueble',
#  'Precio',
#  'Precio por m2',
#  'Moneda',
#  'Número de recámaras',
#  'Número de baños completos',
#  'Número de m2',
#  'Unidad de medida',
#  'Link de la publicación',
#  'Foto de publicación',
#  'Real State Agency?',
#  'Latitud',
#  'Longitud',
#  'ID',
#  'updated_at',
#  'source_of_info']

# %%
'Condición del Inmueble'
'Real State Agency?'

# %% [markdown]
# ## Departamentos analysis

# %%
departamentos_analysis_df = departamentos_df[["Ciudad", "Precio", "Precio por m2", "Número de m2"]]
departamentos_analysis_df
# Out:
#                      Ciudad    Precio  Precio por m2  Número de m2
# 40               Cuauhtémoc   5900000    8104.395604         728.0
# 46                  Tlalpan  29870000   42610.556348         701.0
# 69                  Tlalpan  35874331   59591.911960         602.0
# 81    Cuajimalpa de Morelos  31047000   55639.784946         558.0
# 92           Miguel Hidalgo   1400000    2692.307692         520.0
# ...                     ...       ...            ...           ...
# 3732             Cuauhtémoc    999000   24365.853660          41.0
# 3733             Cuauhtémoc    695000   16951.219510          41.0
# 3734             Cuauhtémoc    705800   17645.000000          40.0
# 3735             Cuauhtémoc   2400000   60000.000000          40.0
# 3736             Cuauhtémoc    999000   24975.000000          40.0
#
# [2783 rows x 4 columns]

# %%
departamentos_analysis_df.shape
# Out:
# (2783, 4)

# %%
departamentos_analysis_df = departamentos_analysis_df[["Ciudad", "Precio", "Precio por m2", "Número de m2"]].groupby('Ciudad').mean().round()
departamentos_analysis_df = departamentos_analysis_df.reset_index()
departamentos_analysis_df
# Out:
#                     Ciudad      Precio  Precio por m2  Número de m2
# 0           Alvaro Obregón   6680888.0        47771.0         136.0
# 1             Azcapotzalco   2053079.0        30655.0          70.0
# 2            Benito Juárez   4599522.0        43049.0         109.0
# 3                 Coyoacán   4238809.0        35109.0         116.0
# 4    Cuajimalpa de Morelos  10035101.0        52628.0         181.0
# 5               Cuauhtémoc   4530508.0        47340.0          93.0
# 6        Gustavo A. Madero   2517163.0        31338.0          81.0
# 7                Iztacalco   1615384.0        25932.0          64.0
# 8               Iztapalapa   1454809.0        21088.0          69.0
# 9   La Magdalena Contreras   7715134.0        42351.0         181.0
# 10          Miguel Hidalgo  13264794.0        72527.0         166.0
# 11                 Tlalpan   6382549.0        41341.0         136.0
# 12                 Tláhuac   1843568.0        17442.0          90.0
# ...

# %%
dt_string = 'apartments'

departamentos_analysis_df.index = pd.Series([dt_string] * len(departamentos_analysis_df))
departamentos_analysis_df = departamentos_analysis_df.reset_index()
departamentos_analysis_df = departamentos_analysis_df.rename(columns={"index":"type_of_property"})
departamentos_analysis_df
# Out:
#    type_of_property                  Ciudad      Precio  Precio por m2  \
# 0        apartments          Alvaro Obregón   6680888.0        47771.0
# 1        apartments            Azcapotzalco   2053079.0        30655.0
# 2        apartments           Benito Juárez   4599522.0        43049.0
# 3        apartments                Coyoacán   4238809.0        35109.0
# 4        apartments   Cuajimalpa de Morelos  10035101.0        52628.0
# 5        apartments              Cuauhtémoc   4530508.0        47340.0
# 6        apartments       Gustavo A. Madero   2517163.0        31338.0
# 7        apartments               Iztacalco   1615384.0        25932.0
# 8        apartments              Iztapalapa   1454809.0        21088.0
# 9        apartments  La Magdalena Contreras   7715134.0        42351.0
# 10       apartments          Miguel Hidalgo  13264794.0        72527.0
# 11       apartments                 Tlalpan   6382549.0        41341.0
# ...

# %%
sorted_columns = ['Ciudad', 'Precio', 'Precio por m2', 'Número de m2', 'type_of_property', ]

# %%
departamentos_analysis_df = departamentos_analysis_df[sorted_columns]
departamentos_analysis_df = departamentos_analysis_df.set_index('Ciudad')
departamentos_analysis_df
# Out:
#                             Precio  Precio por m2  Número de m2  \
# Ciudad
# Alvaro Obregón           6680888.0        47771.0         136.0
# Azcapotzalco             2053079.0        30655.0          70.0
# Benito Juárez            4599522.0        43049.0         109.0
# Coyoacán                 4238809.0        35109.0         116.0
# Cuajimalpa de Morelos   10035101.0        52628.0         181.0
# Cuauhtémoc               4530508.0        47340.0          93.0
# Gustavo A. Madero        2517163.0        31338.0          81.0
# Iztacalco                1615384.0        25932.0          64.0
# Iztapalapa               1454809.0        21088.0          69.0
# La Magdalena Contreras   7715134.0        42351.0         181.0
# Miguel Hidalgo          13264794.0        72527.0         166.0
# Tlalpan                  6382549.0        41341.0         136.0
# Tláhuac                  1843568.0        17442.0          90.0
# ...

# %% [markdown]
# ## Houses analysis

# %%
houses_analysis_df = casas_df[["Ciudad", "Precio", "Precio por m2", "Número de m2"]]
houses_analysis_df
# Out:
#                       Ciudad     Precio  Precio por m2  Número de m2
# 0             Miguel Hidalgo  109616013   54808.006500        2000.0
# 1                 Xochimilco    2000000    1000.000000        2000.0
# 2     La Magdalena Contreras   33000000   19713.261649        1674.0
# 3             Alvaro Obregón   49000000   32885.906040        1490.0
# 4             Miguel Hidalgo  109596083   81363.090572        1347.0
# ...                      ...        ...            ...           ...
# 3276          Miguel Hidalgo    1069899   11887.766670          90.0
# 3381              Iztapalapa     346690    4333.625000          80.0
# 3486     Venustiano Carranza     355000    5071.428571          70.0
# 3559              Cuauhtémoc     750000   11538.461540          65.0
# 3560              Iztapalapa     357092    5493.723077          65.0
#
# [954 rows x 4 columns]

# %%
houses_analysis_df.shape
# Out:
# (954, 4)

# %%
houses_analysis_df = houses_analysis_df[["Ciudad", "Precio", "Precio por m2", "Número de m2"]].groupby('Ciudad').mean().round()
houses_analysis_df = houses_analysis_df.reset_index()
houses_analysis_df
# Out:
#                     Ciudad      Precio  Precio por m2  Número de m2
# 0           Alvaro Obregón  14203529.0        33521.0         405.0
# 1             Azcapotzalco   2192723.0         8903.0         291.0
# 2            Benito Juárez   5607951.0        29095.0         252.0
# 3                 Coyoacán   6919520.0        24013.0         285.0
# 4    Cuajimalpa de Morelos  14621021.0        32909.0         450.0
# 5               Cuauhtémoc   8390498.0        32627.0         283.0
# 6        Gustavo A. Madero   3933335.0        14489.0         270.0
# 7                Iztacalco   3831458.0        17180.0         209.0
# 8               Iztapalapa   3125404.0        13942.0         211.0
# 9   La Magdalena Contreras  11444956.0        27425.0         431.0
# 10          Miguel Hidalgo  24352540.0        49796.0         495.0
# 11                 Tlalpan   7263512.0        22920.0         330.0
# 12                 Tláhuac   2400000.0         8800.0         275.0
# ...

# %%
dt_string = 'houses'

houses_analysis_df.index = pd.Series([dt_string] * len(houses_analysis_df))
houses_analysis_df = houses_analysis_df.reset_index()
houses_analysis_df = houses_analysis_df.rename(columns={"index":"type_of_property"})

sorted_columns = ['Ciudad', 'Precio', 'Precio por m2', 'Número de m2', 'type_of_property', ]

houses_analysis_df = houses_analysis_df[sorted_columns]
houses_analysis_df = houses_analysis_df.set_index('Ciudad')
houses_analysis_df
# Out:
#                             Precio  Precio por m2  Número de m2  \
# Ciudad
# Alvaro Obregón          14203529.0        33521.0         405.0
# Azcapotzalco             2192723.0         8903.0         291.0
# Benito Juárez            5607951.0        29095.0         252.0
# Coyoacán                 6919520.0        24013.0         285.0
# Cuajimalpa de Morelos   14621021.0        32909.0         450.0
# Cuauhtémoc               8390498.0        32627.0         283.0
# Gustavo A. Madero        3933335.0        14489.0         270.0
# Iztacalco                3831458.0        17180.0         209.0
# Iztapalapa               3125404.0        13942.0         211.0
# La Magdalena Contreras  11444956.0        27425.0         431.0
# Miguel Hidalgo          24352540.0        49796.0         495.0
# Tlalpan                  7263512.0        22920.0         330.0
# Tláhuac                  2400000.0         8800.0         275.0
# ...

# %% [markdown]
# ## Append analysis

# %%
analysis_df = departamentos_analysis_df.append(houses_analysis_df).reset_index().sort_values(by = 'Ciudad').reset_index()
del analysis_df['index']
analysis_df
# Out:
#                     Ciudad      Precio  Precio por m2  Número de m2  \
# 0           Alvaro Obregón   6680888.0        47771.0         136.0
# 1           Alvaro Obregón  14203529.0        33521.0         405.0
# 2             Azcapotzalco   2053079.0        30655.0          70.0
# 3             Azcapotzalco   2192723.0         8903.0         291.0
# 4            Benito Juárez   4599522.0        43049.0         109.0
# 5            Benito Juárez   5607951.0        29095.0         252.0
# 6                 Coyoacán   4238809.0        35109.0         116.0
# 7                 Coyoacán   6919520.0        24013.0         285.0
# 8    Cuajimalpa de Morelos  10035101.0        52628.0         181.0
# 9    Cuajimalpa de Morelos  14621021.0        32909.0         450.0
# 10              Cuauhtémoc   4530508.0        47340.0          93.0
# 11              Cuauhtémoc   8390498.0        32627.0         283.0
# 12       Gustavo A. Madero   2517163.0        31338.0          81.0
# ...

# %%
for x in range(len(analysis_df)):
    if analysis_df['Ciudad'][x] == 'Alvaro Obregón':
        analysis_df['Ciudad'][x] = 'Álvaro Obregón'
# Out:
# <ipython-input-420-198ed303b4be>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   analysis_df['Ciudad'][x] = 'Álvaro Obregón'

# %%
# analysis_df.to_csv('csv_files/final_analysis.csv', index = False, encoding = 'latin1')

# %%
complete_dataset_df[["Ciudad", "Precio", "Precio por m2", "Número de m2"]].groupby('Ciudad').mean().round()
# Out:
#                             Precio  Precio por m2  Número de m2
# Ciudad
# Alvaro Obregón           9181311.0        43034.0         225.0
# Azcapotzalco             2109399.0        21882.0         159.0
# Benito Juárez            4780617.0        40543.0         135.0
# Coyoacán                 5938435.0        28074.0         223.0
# Cuajimalpa De Morelos   12694979.0        49926.0         258.0
# Cuajimalpa de Morelos    9026149.0        47312.0         209.0
# Cuauhtémoc               4751079.0        46500.0         104.0
# Gustavo A. Madero        3225249.0        22914.0         175.0
# Iztacalco                2242575.0        23455.0         105.0
# Iztapalapa               2400808.0        17042.0         149.0
# La Magdalena Contreras  10284567.0        32068.0         353.0
# Miguel Hidalgo          14514620.0        69965.0         203.0
# Tlalpan                  6858269.0        31393.0         241.0
# Tláhuac                  1967220.0        15521.0         131.0
# ...

# %%
inmuebles24_df['Precio por m2'].hist()

# %%
meli_df['Precio por m2'].hist()

# %% [markdown]
# # Save a backup of the complete dataset

# %%
# complete_dataset_df.to_csv('csv_files/complete_dataset_cleaned.csv', index = False, encoding = 'utf16')

# %% [markdown]
# ## Analysis of number of properties sold per platform

# %%
complete_dataset_df = pd.read_csv('csv_files/complete_dataset_cleaned.csv', encoding = 'utf16')
complete_dataset_df
# Out:
#                                   Nombre de Publicación            Estado  \
# 0     Magnífica Casa en Una de Las Mejores Colonias ...  Distrito Federal
# 1      Casa en Venta en Xochimilco Santa Cruz Acalpixca  Distrito Federal
# 2                   Se Vende Casa. San Jerónimo Aculco.  Distrito Federal
# 3                      Excelente Residencia en Pedregal  Distrito Federal
# 4     Residencia en Venta en Lomas de Chapultepec, C...  Distrito Federal
# ...                                                 ...               ...
# 3732    Ac ¡últimos Departamentos En La Colonia Centro!  Distrito Federal
# 3733  Venta Departamento En Cento De La Ciudad De Mé...  Distrito Federal
# 3734     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
# 3735  Hermoso Departamento Nuevo En El Corazón Del C...  Distrito Federal
# 3736     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
#
#                       Ciudad                               Colonia  \
# ...

# %%
number_properties_df = complete_dataset_df

# %%
number_properties_df
# Out:
#                                   Nombre de Publicación            Estado  \
# 0     Magnífica Casa en Una de Las Mejores Colonias ...  Distrito Federal
# 1      Casa en Venta en Xochimilco Santa Cruz Acalpixca  Distrito Federal
# 2                   Se Vende Casa. San Jerónimo Aculco.  Distrito Federal
# 3                      Excelente Residencia en Pedregal  Distrito Federal
# 4     Residencia en Venta en Lomas de Chapultepec, C...  Distrito Federal
# ...                                                 ...               ...
# 3732    Ac ¡últimos Departamentos En La Colonia Centro!  Distrito Federal
# 3733  Venta Departamento En Cento De La Ciudad De Mé...  Distrito Federal
# 3734     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
# 3735  Hermoso Departamento Nuevo En El Corazón Del C...  Distrito Federal
# 3736     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
#
#                       Ciudad                               Colonia  \
# ...

# %% [markdown]
# ## Esto es para SQL alchemy

# %%
columns_to_study = ['Ciudad',
 'Tipo de propiedad', 
 'source_of_info']

# %%
number_properties_df[columns_to_study].groupby(['source_of_info', 'Tipo de propiedad']).count()
# Out:
#                                   Ciudad
# source_of_info Tipo de propiedad
# Inmuebles 24   Casa                  706
#                Departamento         1490
# mercado_libre  Casa                  248
#                Departamento         1293

# %%
number_properties_df[['Tipo de propiedad', 'source_of_info']].groupby(['Tipo de propiedad']).count()
# Out:
#                    source_of_info
# Tipo de propiedad
# Casa                          954
# Departamento                 2783

# %% [markdown]
# ## Esto es para Tableau

# %%
number_of_properties_advertised = number_properties_df[columns_to_study].groupby(['Ciudad', 'source_of_info']).count()

# %%
number_of_properties_advertised = number_of_properties_advertised.rename(columns={"Tipo de propiedad":"number_of_ads"})

# %%
number_of_properties_advertised
# Out:
#                                        number_of_ads
# Ciudad                 source_of_info
# Alvaro Obregón         Inmuebles 24              184
#                        mercado_libre             168
# Azcapotzalco           Inmuebles 24              149
#                        mercado_libre              32
# Benito Juárez          Inmuebles 24              517
#                        mercado_libre             296
# Coyoacán               Inmuebles 24              151
#                        mercado_libre              43
# Cuajimalpa de Morelos  Inmuebles 24              133
#                        mercado_libre             147
# Cuauhtémoc             Inmuebles 24              286
#                        mercado_libre             344
# Gustavo A. Madero      Inmuebles 24              117
#                        mercado_libre              41
# Iztacalco              Inmuebles 24               41
#                        mercado_libre              12
# ...

# %%
# number_of_properties_advertised.to_csv('csv_files/number_of_ads_per_district.csv', encoding = 'latin1')

# %%
number_properties_df[[
 'Tipo de propiedad', 
 'source_of_info']].groupby('source_of_info').count()
# Out:
#                 Tipo de propiedad
# source_of_info
# Inmuebles 24                 2196
# mercado_libre                1541

# %% [markdown]
# # This is for the HTML

# %%
number_of_properties_advertised = number_properties_df[['Ciudad',
 'Precio por m2']].groupby('Ciudad').mean()
number_of_properties_advertised.sort_values(by = "Precio por m2", ascending = False)
# Out:
#                         Precio por m2
# Ciudad
# Miguel Hidalgo           69965.211207
# Cuajimalpa de Morelos    48684.123699
# Cuauhtémoc               46499.718361
# Alvaro Obregón           43034.445379
# Benito Juárez            40543.263885
# La Magdalena Contreras   32068.468682
# Tlalpan                  31393.388341
# Coyoacán                 28073.920302
# Iztacalco                23455.416947
# Gustavo A. Madero        22913.566244
# Azcapotzalco             21881.924396
# Venustiano Carranza      18711.079416
# Iztapalapa               17041.720362
# Xochimilco               16919.860365
# Tláhuac                  15521.233087

# %% [markdown]
# # Send the major table to PGadmin

# %%
complete_dataset_df
# Out:
#                                   Nombre de Publicación            Estado  \
# 0     Magnífica Casa en Una de Las Mejores Colonias ...  Distrito Federal
# 1      Casa en Venta en Xochimilco Santa Cruz Acalpixca  Distrito Federal
# 2                   Se Vende Casa. San Jerónimo Aculco.  Distrito Federal
# 3                      Excelente Residencia en Pedregal  Distrito Federal
# 4     Residencia en Venta en Lomas de Chapultepec, C...  Distrito Federal
# ...                                                 ...               ...
# 4009    Ac ¡últimos Departamentos En La Colonia Centro!  Distrito Federal
# 4010  Venta Departamento En Cento De La Ciudad De Mé...  Distrito Federal
# 4011     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
# 4012  Hermoso Departamento Nuevo En El Corazón Del C...  Distrito Federal
# 4013     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
#
#                        Ciudad                               Colonia  \
# ...

# %%
full_dataset_backup = complete_dataset_df

# %%
[x for x in complete_dataset_df.columns]
# Out:
# ['Nombre de Publicación',
#  'Estado',
#  'Ciudad',
#  'Colonia',
#  'Avenida',
#  'Tipo de propiedad',
#  'Tipo de Operación',
#  'Condición del Inmueble',
#  'Precio',
#  'Precio por m2',
#  'Moneda',
#  'Número de recámaras',
#  'Número de baños completos',
#  'Número de m2',
#  'Unidad de medida',
#  'Link de la publicación',
#  'Foto de publicación',
#  'Real State Agency?',
#  'Latitud',
#  'Longitud',
#  'ID',
#  'updated_at',
#  'source_of_info']

# %%
full_dataset_backup = (
    full_dataset_backup.rename(columns = {
        "Nombre de Publicación":"ad_title",
        "Estado":"state",
        "Ciudad":"city",
        "Colonia":"neighborhood",
        "Avenida":"avenue",
        "Tipo de propiedad":"property_type",
        "Tipo de Operación":"operation_type",
        "Condición del Inmueble":"physical_condition",
        "Precio":"price",
        "Precio por m2":"price_per_m2",
        "Moneda":"currency",
        "Número de recámaras":"bedrooms_number",
        "Número de baños completos":"bathrooms_number",
        "Número de m2":"size",
        "Unidad de medida":"size_unit",
        "Link de la publicación":"permalink",
        "Foto de publicación":"thumbnail",
        "Real State Agency?":"seller_agency",
        "Latitud":"latitude",
        "Longitud":"longitude",
        "ID":"ad_id",
    })
)

# %%
full_dataset_backup
# Out:
#                                                ad_title             state  \
# 0     Magnífica Casa en Una de Las Mejores Colonias ...  Distrito Federal
# 1      Casa en Venta en Xochimilco Santa Cruz Acalpixca  Distrito Federal
# 2                   Se Vende Casa. San Jerónimo Aculco.  Distrito Federal
# 3                      Excelente Residencia en Pedregal  Distrito Federal
# 4     Residencia en Venta en Lomas de Chapultepec, C...  Distrito Federal
# ...                                                 ...               ...
# 4009    Ac ¡últimos Departamentos En La Colonia Centro!  Distrito Federal
# 4010  Venta Departamento En Cento De La Ciudad De Mé...  Distrito Federal
# 4011     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
# 4012  Hermoso Departamento Nuevo En El Corazón Del C...  Distrito Federal
# 4013     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
#
#                          city                          neighborhood  \
# ...

# %%
[x for x in full_dataset_backup.columns]
# Out:
# ['ad_title',
#  'state',
#  'city',
#  'neighborhood',
#  'avenue',
#  'property_type',
#  'operation_type',
#  'physical_condition',
#  'price',
#  'price_per_m2',
#  'currency',
#  'bedrooms_number',
#  'bathrooms_number',
#  'size',
#  'size_unit',
#  'permalink',
#  'thumbnail',
#  'seller_agency',
#  'latitude',
#  'longitude',
#  'ad_id',
#  'updated_at',
#  'source_of_info']

# %%
# full_dataset_backup.to_csv('csv_files/full_final_dataset.csv', index = False, encoding = 'utf16')

# %%
full_dataset_backup = pd.read_csv('csv_files/full_final_dataset.csv', encoding = 'utf16')
full_dataset_backup
# Out:
#                                                ad_title             state  \
# 0     Magnífica Casa en Una de Las Mejores Colonias ...  Distrito Federal
# 1      Casa en Venta en Xochimilco Santa Cruz Acalpixca  Distrito Federal
# 2                   Se Vende Casa. San Jerónimo Aculco.  Distrito Federal
# 3                      Excelente Residencia en Pedregal  Distrito Federal
# 4     Residencia en Venta en Lomas de Chapultepec, C...  Distrito Federal
# ...                                                 ...               ...
# 4009    Ac ¡últimos Departamentos En La Colonia Centro!  Distrito Federal
# 4010  Venta Departamento En Cento De La Ciudad De Mé...  Distrito Federal
# 4011     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
# 4012  Hermoso Departamento Nuevo En El Corazón Del C...  Distrito Federal
# 4013     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
#
#                          city                          neighborhood  \
# ...

# %% [markdown]
# # Send the data to PGadmin

# %%
from sqlalchemy import create_engine

# %%
# !pip install psycopg2

# %%
### Create database connection

db_details = "postgres:karen@localhost:5432/properties_db"
connection_string = f'postgresql://{db_details}'

engine = create_engine(connection_string, encoding="utf16")


# Confirm tables
engine.table_names()
# Out:
# ['properties']

# %%
engine.encoding
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-85-e9462971e679> in <module>
# ----> 1 engine.encoding
#
# AttributeError: 'Engine' object has no attribute 'encoding'

# %%
### Load DataFrames into database

test.to_sql(name='properties', con=engine, if_exists='replace', index=False)
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# <ipython-input-78-c5c921a0f24a> in <module>
#       1 ### Load DataFrames into database
#       2
# ----> 3 test.to_sql(name='properties', con=engine, if_exists='replace', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2651         from pandas.io import sql
#    2652
# -> 2653         sql.to_sql(
#    2654             self,
#    2655             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     510         )
#     511
# --> 512     pandas_sql.to_sql(
#     513         frame,
#     514         name,
#
# ...

# %%
pd.read_sql("select * from properties", engine)
# Out:
# Empty DataFrame
# Columns: [ad_title, state, city, neighborhood, avenue, property_type, operation_type, physical_condition, price, price_per_m2, currency, bedrooms_number, bathrooms_number, size, size_unit, permalink, thumbnail, seller_agency, latitude, longitude, ad_id, updated_at, source_of_info]
# Index: []
#
# [0 rows x 23 columns]

# %% [markdown]
# # Code for FLask to turn into the JSON

# %%
full_dataset_backup
# Out:
#                                                ad_title             state  \
# 0     Magnífica Casa en Una de Las Mejores Colonias ...  Distrito Federal
# 1      Casa en Venta en Xochimilco Santa Cruz Acalpixca  Distrito Federal
# 2                   Se Vende Casa. San Jerónimo Aculco.  Distrito Federal
# 3                      Excelente Residencia en Pedregal  Distrito Federal
# 4     Residencia en Venta en Lomas de Chapultepec, C...  Distrito Federal
# ...                                                 ...               ...
# 4009    Ac ¡últimos Departamentos En La Colonia Centro!  Distrito Federal
# 4010  Venta Departamento En Cento De La Ciudad De Mé...  Distrito Federal
# 4011     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
# 4012  Hermoso Departamento Nuevo En El Corazón Del C...  Distrito Federal
# 4013     Tg Venta De Departamento De 2 Recamaras 1 Baño  Distrito Federal
#
#                          city                          neighborhood  \
# ...

# %% [markdown]
# ### Mercado Libre dataset

# %%
(
    full_dataset_backup
    .loc[full_dataset_backup['source_of_info'] == 'mercado_libre']
    .reset_index()
    .drop(['index'], inplace=False, axis=1)
    .to_json(force_ascii = True, orient="records")
)
# Out:
# '[{"ad_title":"Casa En Venta, Miguel Hidalgo, Ciudad De M\\u00e9xico","state":"Distrito Federal","city":"Miguel Hidalgo","neighborhood":"Lomas de Chapultepec I Secci\\u00f3n","avenue":"Paseo de las Palmas","property_type":"Casa","operation_type":"Venta","physical_condition":"not specified","price":69500000,"price_per_m2":87421.38365,"currency":"MXN","bedrooms_number":3,"bathrooms_number":4,"size":795.0,"size_unit":"m\\u00b2","permalink":"https:\\/\\/casa.mercadolibre.com.mx\\/MLM-786181310-casa-en-venta-miguel-hidalgo-ciudad-de-mexico-_JM","thumbnail":"http:\\/\\/http2.mlstatic.com\\/D_796522-MLM42242895820_062020-I.jpg","seller_agency":"True","latitude":19.411036,"longitude":-99.22981,"ad_id":"MLM786181310","updated_at":"04\\/12\\/2021","source_of_info":"mercado_libre"},{"ad_title":"Casa En Venta, Miguel Hidalgo, Ciudad De M\\u00e9xico","state":"Distrito Federal","city":"Miguel Hidalgo","neighborhood":"Lomas De Reforma","avenue":"Alc\\u00e1zar de Toledo","property_type":"Casa","oper
# ...

# %% [markdown]
# ### Inmuebles 24 dataset

# %%
(
    full_dataset_backup
    .loc[full_dataset_backup['source_of_info'] == 'Inmuebles 24']
    .reset_index()
    .drop(['index'], inplace=False, axis=1)
    .to_json(force_ascii = True, orient="records")
)
# Out:
# '[{"ad_title":"Magn\\u00edfica Casa en Una de Las Mejores Colonias de La Ciudad de M\\u00e9xico","state":"Distrito Federal","city":" Miguel Hidalgo","neighborhood":"Lomas de Chapultepec","avenue":"Sierra Gorda","property_type":"Casa","operation_type":"Venta","physical_condition":"40  Antig\\u00fcedad","price":109616013,"price_per_m2":54808.0065,"currency":"MXN","bedrooms_number":3,"bathrooms_number":3,"size":2000.0,"size_unit":"m\\u00b2","permalink":"https:\\/\\/www.inmuebles24.com\\/propiedades\\/magnifica-casa-en-una-de-las-mejores-colonias-de-la-60895016.html","thumbnail":"https:\\/\\/img10.naventcdn.com\\/avisos\\/18\\/00\\/60\\/89\\/50\\/16\\/360x266\\/253894538.jpg","seller_agency":"coldwell-banker-invest-asociada-con-id-15246-7_2","latitude":19.421469,"longitude":-99.225289,"ad_id":"60895016","updated_at":"04\\/22\\/2021","source_of_info":"Inmuebles 24"},{"ad_title":"Casa en Venta en Xochimilco Santa Cruz Acalpixca","state":"Distrito Federal","city":" Xochimilco","neighborhood
# ...
